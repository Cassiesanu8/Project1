# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv")

# %%
import seaborn as sns
# %matplotlib inline

# %%
df.head()
# Out:
#   School DBN  ... Percent Scoring CR
# 0     01M034  ...                 na
# 1     01M034  ...                 na
# 2     01M034  ...                 na
# 3     01M140  ...                 na
# 4     01M140  ...                 na
#
# [5 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=212331, step=1)

# %%
df.values
# Out:
# array([['01M034', 'P.S. 034 Franklin D. Roosevelt', 'K-8', ..., 's',
#         'na', 'na'],
#        ['01M034', 'P.S. 034 Franklin D. Roosevelt', 'K-8', ..., '43.8',
#         'na', 'na'],
#        ['01M034', 'P.S. 034 Franklin D. Roosevelt', 'K-8', ..., '22.2',
#         'na', 'na'],
#        ...,
#        ['84X717', 'Icahn Charter School', 'K-8', ..., 's', 'na', 'na'],
#        ['84X717', 'Icahn Charter School', 'K-8', ..., 's', 'na', 'na'],
#        ['84X717', 'Icahn Charter School', 'K-8', ..., 's', 'na', 'na']],
#       dtype=object)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (212331, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   212331 non-null  object
#  1   School Name                  212331 non-null  object
#  2   School Level                 212331 non-null  object
#  3   Regents Exam                 212321 non-null  object
#  4   Year                         212331 non-null  int64
#  5   Total Tested                 212331 non-null  int64
#  6   Mean Score                   212331 non-null  object
#  7   Number Scoring Below 65      212331 non-null  object
#  8   Percent Scoring Below 65     212331 non-null  object
#  9   Number Scoring 65 or Above   212331 non-null  object
#  10  Percent Scoring 65 or Above  212331 non-null  object
#  11  Number Scoring 80 or Above   212331 non-null  object
# ...

# %%
df1 = df.dropna()
print(df1)
# Out:
#        School DBN  ... Percent Scoring CR
# 0          01M034  ...                 na
# 1          01M034  ...                 na
# 2          01M034  ...                 na
# 3          01M140  ...                 na
# 4          01M140  ...                 na
# ...           ...  ...                ...
# 212326     84X717  ...                 na
# 212327     84X717  ...                 na
# 212328     84X717  ...                 na
# 212329     84X717  ...                 na
# 212330     84X717  ...                 na
#
# [212321 rows x 15 columns]

# %%
df["School Name"]
# Out:
# 0         P.S. 034 Franklin D. Roosevelt
# 1         P.S. 034 Franklin D. Roosevelt
# 2         P.S. 034 Franklin D. Roosevelt
# 3                 P.S. 140 Nathan Straus
# 4                 P.S. 140 Nathan Straus
#                        ...
# 212326              Icahn Charter School
# 212327              Icahn Charter School
# 212328              Icahn Charter School
# 212329              Icahn Charter School
# 212330              Icahn Charter School
# Name: School Name, Length: 212331, dtype: object

# %%
School_df = df["School Name"]

# %%
School_df.head()
# Out:
# 0    P.S. 034 Franklin D. Roosevelt
# 1    P.S. 034 Franklin D. Roosevelt
# 2    P.S. 034 Franklin D. Roosevelt
# 3            P.S. 140 Nathan Straus
# 4            P.S. 140 Nathan Straus
# Name: School Name, dtype: object

# %%
mean_df = df["Mean Score"]
mean_df.head()
# Out:
# 0       s
# 1    77.9
# 2      74
# 3       s
# 4       s
# Name: Mean Score, dtype: object

# %%
dbn_df = df["School DBN"]
dbn_df.head()
# Out:
# 0    01M034
# 1    01M034
# 2    01M034
# 3    01M140
# 4    01M140
# Name: School DBN, dtype: object

# %%
sns.barplot(x = dbn_df, y = School_df)

# %%
# Out:
#   File "<ipython-input-71-1a54b4faecce>", line 5
#     plt.title("School v Mean')
#                               ^
# SyntaxError: EOL while scanning string literal

# %%
subset = df[["School Name", "Regents Exam", "Mean Score"]]
subset.head()
# Out:
#                       School Name         Regents Exam Mean Score
# 0  P.S. 034 Franklin D. Roosevelt  Common Core Algebra          s
# 1  P.S. 034 Franklin D. Roosevelt   Living Environment       77.9
# 2  P.S. 034 Franklin D. Roosevelt   Living Environment         74
# 3          P.S. 140 Nathan Straus  Common Core Algebra          s
# 4          P.S. 140 Nathan Straus  Common Core Algebra          s

# %%
df.loc[(df["Regents Exam"] == Living Environment) & (df("Mean Score") > 70), ["Regents Exam", "School Name", "Mean Score"]]
# Out:
#   File "<ipython-input-67-35153cbbed6a>", line 1
#     df.loc[(df["Regents Exam"] == Living Environment) & (df("Mean Score") > 70), ["Regents Exam", "School Name", "Mean Score"]]
#                                                    ^
# SyntaxError: invalid syntax

# %%
df.groupby(["School Name", "Regents Exam"])["Mean Score"].count()
# Out:
# School Name                                         Regents Exam
# 47 The American Sign Language and English Secondar  Algebra2/Trigonometry              25
#                                                     Common Core Algebra                35
#                                                     Common Core Algebra2               16
#                                                     Common Core English                32
#                                                     Common Core Geometry               31
#                                                                                        ..
# Young Women's Leadership School, Queens             Integrated Algebra                 22
#                                                     Living Environment                 35
#                                                     Physical Settings/Chemistry        34
#                                                     Physical Settings/Earth Science    35
# ...

# %%
#Use the iloc function I chose the specific school of my interest using the index value
df.iloc[[8, 9, 10, 11]]
# Out:
#    School DBN           School Name  ... Number Scoring CR Percent Scoring CR
# 8      01M184  P.S. 184m Shuang Wen  ...                48                 98
# 9      01M184  P.S. 184m Shuang Wen  ...                40               78.4
# 10     01M184  P.S. 184m Shuang Wen  ...                50                 98
# 11     01M184  P.S. 184m Shuang Wen  ...                na                 na
#
# [4 rows x 15 columns]

# %%
#I gave the name to the selection of the new dataset
Shuang = df.iloc[[8, 9, 10, 11]]
Shuang.shape
# Out:
# (4, 15)

# %%
#I used the drop functions to drop the columns that i selected to create a new dataset 
Other_Schools = df.drop([8, 9, 10, 11])
Other_Schools.shape
# Out:
# (212327, 15)

# %%
sns.displot(Shuang["Mean Score"], bins = 75)

# %%
sns.displot(subset["Mean Score"], bins = 75)

# %%
sns.displot(Other_Schools["Mean Score"], bins = 200)

# %%
#I tried using this code to select values with specific condtions but it dit not work
df[df['Mean Score'] > 70][df['Regents Exam' == 'Living Condition']
# Out:
#   File "<ipython-input-68-f988f70ca788>", line 2
#     df[df['Mean Score'] > 70][df['Regents Exam' == 'Living Condition']
#                                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
sns.pairplot(Shuang)

# %%
sns.pairplot(Other_Schools)

# %%
sns.pairplot(Shuang, hue="Mean Score")

# %%
sns.pairplot(Other_Schools, hue="Mean Score")
